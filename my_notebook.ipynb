# %%
# !pip install torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torch
#   Downloading torch-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting filelock (from torch)
#   Downloading filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /share/apps/NYUAD5/miniconda/3-4.11.0/envs/jupyter7/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in /share/apps/NYUAD5/miniconda/3-4.11.0/envs/jupyter7/lib/python3.12/site-packages (from torch) (80.9.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ss17886/.local/lib/python3.12/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /home/ss17886/.local/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /share/apps/NYUAD5/miniconda/3-4.11.0/envs/jupyter7/lib/python3.12/site-packages (from torch) (3.1.6)
# Collecting fsspec>=0.8.5 (from torch)
#   Downloading fsspec-2026.3.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.2)
# Collecting cuda-bindings<14,>=13.0.3 (from torch)
#   Downloading cuda_bindings-13.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (2.3 kB)
# Collecting nvidia-cudnn-cu13==9.19.0.56 (from torch)
#   Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl.metadata (1.9 kB)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /home/ss17886/.local/lib/python3.12/site-packages (from torch) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /home/ss17886/.local/lib/python3.12/site-packages (from torch) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /home/ss17886/.local/lib/python3.12/site-packages (from torch) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /home/ss17886/.local/lib/python3.12/site-packages (from torch) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.96)
# Collecting nvidia-cufft==12.0.0.61.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch)
#   Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (10.4.0.35)
# Collecting nvidia-cusolver==12.0.4.66.* (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch)
#   Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /home/ss17886/.local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch) (13.0.85)
# Collecting cuda-pathfinder~=1.1 (from cuda-bindings<14,>=13.0.3->torch)
#   Downloading cuda_pathfinder-1.5.3-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ss17886/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /share/apps/NYUAD5/miniconda/3-4.11.0/envs/jupyter7/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Downloading torch-2.11.0-cp312-cp312-manylinux_2_28_x86_64.whl (530.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 530.7/530.7 MB 58.6 MB/s  0:00:07m0:00:0100:01
# Downloading nvidia_cudnn_cu13-9.19.0.56-py3-none-manylinux_2_27_x86_64.whl (366.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 366.1/366.1 MB 66.3 MB/s  0:00:04m0:00:0100:01
# Downloading cuda_bindings-13.2.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 50.2 MB/s  0:00:00
# Downloading cuda_pathfinder-1.5.3-py3-none-any.whl (49 kB)
# Downloading nvidia_cufft-12.0.0.61-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (214.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 214.1/214.1 MB 80.9 MB/s  0:00:02m0:00:0100:01
# Downloading nvidia_cusolver-12.0.4.66-py3-none-manylinux_2_27_x86_64.whl (200.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.9/200.9 MB 76.0 MB/s  0:00:02m0:00:0100:01
# Downloading fsspec-2026.3.0-py3-none-any.whl (202 kB)
# Downloading filelock-3.29.0-py3-none-any.whl (39 kB)
# Installing collected packages: nvidia-cufft, nvidia-cudnn-cu13, fsspec, filelock, cuda-pathfinder, nvidia-cusolver, cuda-bindings, torch
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [torch]32m7/8 [torch]indings]r]3]
# Successfully installed cuda-bindings-13.2.0 cuda-pathfinder-1.5.3 filelock-3.29.0 fsspec-2026.3.0 nvidia-cudnn-cu13-9.19.0.56 nvidia-cufft-12.0.0.61 nvidia-cusolver-12.0.4.66 torch-2.11.0

# %%
print("Hello World")
# Out:
# Hello World

# %%
import torch
import platform
import os
import subprocess

print("=" * 60)
print("SYSTEM INFORMATION")
print("=" * 60)
print(f"Hostname: {platform.node()}")
print(f"Operating System: {platform.system()} {platform.release()}")
print(f"Python Version: {platform.python_version()}")
print(f"PyTorch Version: {torch.__version__}")

print("\n" + "=" * 60)
print("CPU INFORMATION")
print("=" * 60)
print(f"CPU Cores Available: {os.cpu_count()}")

print("\n" + "=" * 60)
print("CUDA / GPU INFORMATION")
print("=" * 60)

if torch.cuda.is_available():
    num_gpus = torch.cuda.device_count()
    print(f"CUDA Available: Yes")
    print(f"Number of GPUs: {num_gpus}")
    
    for i in range(num_gpus):
        props = torch.cuda.get_device_properties(i)
        print(f"\nGPU {i}:")
        print(f"  Name: {torch.cuda.get_device_name(i)}")
        print(f"  Total Memory: {props.total_memory / 1024**3:.2f} GB")
        print(f"  Compute Capability: {props.major}.{props.minor}")
        print(f"  Multiprocessors: {props.multi_processor_count}")
    
    print(f"\nCurrent Device: GPU {torch.cuda.current_device()}")
    
    # Optional: show nvidia-smi output if available
    try:
        print("\n" + "=" * 60)
        print("NVIDIA-SMI")
        print("=" * 60)
        result = subprocess.run(
            ["nvidia-smi"],
            capture_output=True,
            text=True,
            check=True
        )
        print(result.stdout)
    except Exception:
        print("nvidia-smi not available.")
else:
    print("CUDA Available: No")
    print("Running on CPU only.")

print("\n" + "=" * 60)
print("DEVICE SELECTION")
print("=" * 60)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# /home/ss17886/.local/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:307: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# ============================================================
# SYSTEM INFORMATION
# ============================================================
# Hostname: cn012
# Operating System: Linux 4.18.0-513.5.1.el8_9.x86_64
# Python Version: 3.12.0
# PyTorch Version: 2.11.0+cu130
#
# ============================================================
# CPU INFORMATION
# ============================================================
# CPU Cores Available: 128
#
# ============================================================
# CUDA / GPU INFORMATION
# ============================================================
# CUDA Available: Yes
# Number of GPUs: 1
#
# GPU 0:
#   Name: NVIDIA A100 80GB PCIe
#   Total Memory: 79.25 GB
#   Compute Capability: 8.0
#   Multiprocessors: 108
#
# Current Device: GPU 0
#
# ============================================================
# NVIDIA-SMI
# ============================================================
# Fri Apr 24 17:52:22 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.105.08             Driver Version: 580.105.08     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100 80GB PCIe          Off |   00000000:25:00.0 Off |                    0 |
# | N/A   33C    P0             47W /  300W |       4MiB /  81920MiB |      0%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
#
#
# ============================================================
# DEVICE SELECTION
# ============================================================
# Using device: cuda
